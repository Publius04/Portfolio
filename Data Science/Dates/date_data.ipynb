# %%
import pandas as pd
import os
import plotly.express as px

# %%
pwd = os.getcwd()
pwd
# Out:
# 'c:\\Users\\dylan\\Desk\\Programming\\Data Science\\Dates'

# %%
df = pd.read_excel(pwd + "\\Date_Fruit_Datasets.xlsx")
df
# Out:
#        AREA  PERIMETER  MAJORAXIS  MINORAXIS  ECCENTRICITY   EQDIASQ  \
# 0    422163  2378.9080   837.8484   645.6693        0.6373  733.1539
# 1    338136  2085.1440   723.8198   595.2073        0.5690  656.1464
# 2    526843  2647.3940   940.7379   715.3638        0.6494  819.0222
# 3    416063  2351.2100   827.9804   645.2988        0.6266  727.8378
# 4    347562  2160.3540   763.9877   582.8359        0.6465  665.2291
# ..      ...        ...        ...        ...           ...       ...
# 893  255403  1925.3650   691.8453   477.1796        0.7241  570.2536
# 894  365924  2664.8230   855.4633   551.5447        0.7644  682.5752
# 895  254330  1926.7360   747.4943   435.6219        0.8126  569.0545
# 896  238955  1906.2679   716.6485   441.8297        0.7873  551.5859
# 897  343792  2289.2720   823.8438   534.7757        0.7607  661.6113
#
#      SOLIDITY  CONVEX_AREA  EXTENT  ASPECTRATIO  ...  kurtosisRR  kurtosisRG  \
# ...

# %%
cdf = df.copy()
cdf
# Out:
#        AREA  PERIMETER  MAJORAXIS  MINORAXIS  ECCENTRICITY   EQDIASQ  \
# 0    422163  2378.9080   837.8484   645.6693        0.6373  733.1539
# 1    338136  2085.1440   723.8198   595.2073        0.5690  656.1464
# 2    526843  2647.3940   940.7379   715.3638        0.6494  819.0222
# 3    416063  2351.2100   827.9804   645.2988        0.6266  727.8378
# 4    347562  2160.3540   763.9877   582.8359        0.6465  665.2291
# ..      ...        ...        ...        ...           ...       ...
# 893  255403  1925.3650   691.8453   477.1796        0.7241  570.2536
# 894  365924  2664.8230   855.4633   551.5447        0.7644  682.5752
# 895  254330  1926.7360   747.4943   435.6219        0.8126  569.0545
# 896  238955  1906.2679   716.6485   441.8297        0.7873  551.5859
# 897  343792  2289.2720   823.8438   534.7757        0.7607  661.6113
#
#      SOLIDITY  CONVEX_AREA  EXTENT  ASPECTRATIO  ...  kurtosisRR  kurtosisRG  \
# ...

# %%
date_types = list(cdf["Class"].unique())
date_types
# Out:
# ['BERHI', 'DEGLET', 'DOKOL', 'IRAQI', 'ROTANA', 'SAFAVI', 'SOGAY']

# %%
Berhi_data = cdf.loc[cdf["Class"] == "BERHI"]
Berhi_data.drop(columns="Class")
# Out:
#       AREA  PERIMETER  MAJORAXIS  MINORAXIS  ECCENTRICITY   EQDIASQ  SOLIDITY  \
# 0   422163  2378.9080   837.8484   645.6693        0.6373  733.1539    0.9947
# 1   338136  2085.1440   723.8198   595.2073        0.5690  656.1464    0.9974
# 2   526843  2647.3940   940.7379   715.3638        0.6494  819.0222    0.9962
# 3   416063  2351.2100   827.9804   645.2988        0.6266  727.8378    0.9948
# 4   347562  2160.3540   763.9877   582.8359        0.6465  665.2291    0.9908
# ..     ...        ...        ...        ...           ...       ...       ...
# 60  445290  2435.3889   857.8929   663.8074        0.6335  752.9680    0.9940
# 61  375936  2255.8411   817.8654   589.0416        0.6937  691.8501    0.9945
# 62  439650  2447.7371   890.0155   635.1306        0.7005  748.1843    0.9926
# 63  433338  2423.3010   836.3414   664.9469        0.6065  742.7941    0.9932
# 64  500669  2580.3069   913.3773   702.0745        0.6397  798.4182    0.9948
#
# ...

# %%
Berhi_data.describe()
# Out:
#                 AREA    PERIMETER   MAJORAXIS   MINORAXIS  ECCENTRICITY  \
# count      65.000000    65.000000   65.000000   65.000000     65.000000
# mean   405213.446154  2321.504669  815.370329  634.656000      0.621369
# std     50349.896711   145.161504   51.749149   48.363478      0.066413
# min    288730.000000  1997.627000  715.426100  497.809500      0.420200
# 25%    381508.000000  2255.841100  784.119100  600.328400      0.600700
# 50%    409032.000000  2337.225100  818.814600  644.689100      0.634500
# 75%    433338.000000  2407.507100  840.182100  664.545100      0.654800
# max    546063.000000  2714.948000  940.737900  766.453600      0.740900
#
#           EQDIASQ   SOLIDITY    CONVEX_AREA     EXTENT  ASPECTRATIO  ...  \
# count   65.000000  65.000000      65.000000  65.000000    65.000000  ...
# mean   716.904234   0.993957  407666.153846   0.766549     1.288515  ...
# std     44.867300   0.002493   50598.908769   0.021058     0.081627  ...
# ...

# %%
Sogay_data = cdf.loc[cdf["Class"] == "SOGAY"]
Sogay_data.drop(columns="Class")
# Out:
#        AREA  PERIMETER  MAJORAXIS  MINORAXIS  ECCENTRICITY   EQDIASQ  \
# 804  272029  1927.4420   700.2120   497.2475        0.7041  588.5220
# 805  328825  2226.3210   845.2898   520.5521        0.7879  647.0494
# 806  378039  2343.2290   902.6270   535.5190        0.8050  693.7825
# 807  324530  2168.5410   805.7068   514.7833        0.7693  642.8098
# 808  332254  2172.4651   829.7610   513.4503        0.7856  650.4144
# ..      ...        ...        ...        ...           ...       ...
# 893  255403  1925.3650   691.8453   477.1796        0.7241  570.2536
# 894  365924  2664.8230   855.4633   551.5447        0.7644  682.5752
# 895  254330  1926.7360   747.4943   435.6219        0.8126  569.0545
# 896  238955  1906.2679   716.6485   441.8297        0.7873  551.5859
# 897  343792  2289.2720   823.8438   534.7757        0.7607  661.6113
#
#      SOLIDITY  CONVEX_AREA  EXTENT  ASPECTRATIO  ...  skewRB  kurtosisRR  \
# ...

# %%
Sogay_data["AREA"].describe()
# Out:
# count        94.000000
# mean     286872.957447
# std       47198.546528
# min      196561.000000
# 25%      247499.000000
# 50%      284757.000000
# 75%      324408.500000
# max      378039.000000
# Name: AREA, dtype: float64

# %%
fig = px.scatter(Berhi_data, x="PERIMETER", y="AREA")
fig.show()

# %%
fig = px.scatter(Sogay_data, x="PERIMETER", y="AREA")
fig.show()

# %%
fig = px.scatter(cdf, x="PERIMETER", y="AREA")
fig.show()
